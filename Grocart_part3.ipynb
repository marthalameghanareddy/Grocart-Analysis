# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
final=pd.read_csv('/content/drive/My Drive/Grocart_Project/final.csv')

# %%
train = final[final.eval_set == 'train']
train.head()
# Out:
#    user_id  user_num_orders  ...  order_hour_of_day  days_since_prior_order
# 0        1               10  ...                  8                    14.0
# 3       21               33  ...                 12                    28.0
# 5       43               11  ...                 11                    26.0
# 6       52               27  ...                 16                     3.0
# 7       67               24  ...                 11                     5.0
#
# [5 rows x 35 columns]

# %%
final.shape
# Out:
# (8474661, 35)

# %%
train.shape
# Out:
# (8474661, 35)

# %%
order_products_train=pd.read_csv('/content/drive/My Drive/Grocart_Project/order_products_train.csv')
order_products_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
train = train.merge(order_products_train[['product_id', 'order_id', 'reordered']], on=['product_id', 'order_id'], how='left')
train.head()
# Out:
#    user_id  user_num_orders  ...  days_since_prior_order  reordered
# 0        1               10  ...                    14.0        1.0
# 1       21               33  ...                    28.0        NaN
# 2       43               11  ...                    26.0        NaN
# 3       52               27  ...                     3.0        NaN
# 4       67               24  ...                     5.0        1.0
#
# [5 rows x 36 columns]

# %%
train.reordered.fillna(0, inplace=True)
train.replace(np.nan, 0, inplace = True)

# %%
train = train.drop(['eval_set', 'order_id'], axis = 1)
train.to_csv('/content/drive/My Drive/Grocart_Project/train.csv', index = False)
train.head()
# Out:
#    user_id  user_num_orders  ...  days_since_prior_order  reordered
# 0        1               10  ...                    14.0        1.0
# 1       21               33  ...                    28.0        0.0
# 2       43               11  ...                    26.0        0.0
# 3       52               27  ...                     3.0        0.0
# 4       67               24  ...                     5.0        1.0
#
# [5 rows x 34 columns]

# %%
train.shape
# Out:
# (8474661, 34)
